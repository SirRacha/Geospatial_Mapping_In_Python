# %% [markdown]
# # Now let's look at this data plotted geospatially

# %%
import json
import requests
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/RoscoeBColtrane/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#  A function to get Lat/Long coords returned from having street addresses in 
#   GoogleMaps API.  40,000 FREE req's PER MONTH. $0.005 AFTER
#   WALKTHROUGH IS HERE-- https://medium.com/datadriveninvestor/turning-addresses-into-coordinates-de6198b22905

import googlemaps
KEY = 'INSERT_MAPS_API_KEY_HERE'
gmaps = googlemaps.Client(key=KEY)

#  Now, using the function geocode of the Google Maps client passing the 
#  address as a string one will receive a JSON with the following structure:

# The coordinates in latitude and longitude will be in the geometry section.OF THE GEOJSON

def get_coordinates(address):
    city = '<City Name>, <Country>'
    geocode_result = gmaps.geocode(str(address) +' '+ city)
    if len(geocode_result) > 0:
        return list(geocode_result[0]['geometry']['location'].values())
    else:
        return [np.NaN, np.NaN]

#  Including the name of the city and country is the best way to increase the 
#   performance of the API.


#  APPEND TO DATAFRAME
coordinates = df2['Address'].apply(lambda x: pd.Series(get_coordinates(x), index=['LATITUDE', 'LONGITUDE']))
df2 = pd.concat([df2[:], coordinates[:]], axis="columns")

# %%
bestPizza = pd.read_csv("../data/PizzaEssentials.csv",index_col=False)
restPandI = pd.read_csv("../data/restPandI.csv")
print(restPandI.shape)
allPizza = pd.read_csv("../data/restPizza.csv")
print(allPizza.shape)
subway = pd.read_csv("../data/subwayStations.csv")
print(subway.shape)
# Out:
#    Longitude  Latitude                 Name  \
# 0  -73.99324  40.70258  Grimaldi's Pizzeria
# 1  -73.93488  40.79715     Patsy's Pizzeria
# 2  -73.98130  40.59474  L&B Spumoni Gardens
# 3  -73.99459  40.72301     Prince St. Pizza
# 4  -73.88825  40.85421   Mario's Restaurant
#
#                                              Comment  \
# 0  also coal fired. A descendant of Lombardi's pi...
# 1  an OG joint in East Harlem. prolly the 4 pizze...
# 2  since 1939, the real deal ice cream of Italy.....
# 3  NOLITA!!! neighborhood slice joint. reimaginin...
# 4  Old style classic.  Pizza is ordered Off-Menu!...
#
#                                                  URL
# 0  https://www.google.com/maps/place/Grimaldi's+P...
# 1  https://www.google.com/maps/place/Patsy's+Pizz...
# 2  https://www.google.com/maps/place/L%26B+Spumon...
# 3  https://www.google.com/maps/place/Prince+St.+P...
# 4  https://www.google.com/maps/place/Mario's/data...

# %%
list(restPandI)
# Out:
# ['Unnamed: 0',
#  'CAMIS',
#  'DBA',
#  'BORO',
#  'BUILDING',
#  'STREET',
#  'ZIPCODE',
#  'PHONE',
#  'CUISINE DESCRIPTION',
#  'INSPECTION DATE',
#  'ACTION',
#  'VIOLATION CODE',
#  'VIOLATION DESCRIPTION',
#  'CRITICAL FLAG',
#  'SCORE',
#  'GRADE',
#  'GRADE DATE',
#  'RECORD DATE',
#  'INSPECTION TYPE',
#  'Latitude',
#  'Longitude',
#  'Community Board',
#  'Council District',
#  'Census Tract',
#  'BIN',
#  'BBL',
#  'NTA']

# %% [markdown]
# # Google Maps directly
# ## Need to do this in terminal first AND create a google maps API KEY
# pip install gmaps
#
# jupyter nbextension enable --py gmaps

# %%
import gmaps
import gmaps.datasets
# Your Google API key
import os
#gmaps.configure(api_key=os.environ["GOOGLE_API_KEY"])
gmaps.configure(api_key="API_KEY") 

####IF NEED TO REMOVE COLUMNS BC OF EXCESSIVE RUNNING!
#bestPizza = bestPizza.drop('location', axis=1)
#bestPizza = bestPizza.drop('locations', axis=1)

#bestPizza = bestPizza[bestPizza['chain_name'] == 'Name']
bestPizza['locations'] = bestPizza[['Latitude', 'Longitude']].apply(tuple, axis=1)
locations = bestPizza['locations'] 

fig = gmaps.figure()
pizza_layer = gmaps.symbol_layer(
    locations, fill_color="green", stroke_color="green", scale=2
)
fig.add_layer(pizza_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps
gmaps.configure(api_key="API_KEY_HERE)
fig = gmaps.figure()
locations = [(46.1, 5.2), (46.2, 5.3), (46.3, 5.4)]
fig.add_layer(gmaps.heatmap_layer(locations))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ## FOR BOKEH  (API doesn't work very well here)
# ### We'll use some source code from here
# https://www.bigendiandata.com/2017-06-27-Mapping_in_Jupyter/
# ### that creates a function and is a really creative way to read in data, ex:

# %%
DATASETS_URL = "https://github.com/ageron/handson-ml/raw/master/datasets"
import os
import tarfile
from six.moves import urllib

HOUSING_PATH = "datasets/housing"
HOUSING_URL = DATASETS_URL + "/housing/housing.tgz"

def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.exists(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()
    
fetch_housing_data()
import pandas as pd

def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)
housing = load_housing_data()
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ## but since we have already read our data in from a local directory, we'll skip that step
# ## And go into making a map with bokeh. it uses the Google Maps API and visual style
# BUT, Google Maps API is not allowing calls!  https://github.com/bokeh/bokeh/issues/3737

# %% [raw]
# from bokeh.io import output_file, output_notebook, show
# from bokeh.models import (
#   GMapOptions, ColumnDataSource, Circle, LogColorMapper, BasicTicker, ColorBar,
#     DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
# )
# from bokeh.models.mappers import ColorMapper, LinearColorMapper
# from bokeh.palettes import Viridis5
# # https://docs.bokeh.org/en/latest/docs/user_guide/geo.html#google-maps
# from bokeh.plotting import gmap
#
# map_options = GMapOptions(lat=40.730610, lng=-73.935242, map_type="roadmap", zoom=151)
#
# api_key = "AIzaSyAyTUcgbuwbey0p5n5q6BK-PMGHAoAgiJg"
#
# # For GMaps to function, Google requires you obtain and enable an API key:
# #
# #     https://developers.google.com/maps/documentation/javascript/get-api-key
# #
# # Replace the value below with your personal API key:
# #plot = gmap("api_key", map_options, title="New York 'Za'")
#
#
# #older way for Bokeh
# '''
# plot=GMapPlot(x_range=Range1d(), y_range=Range1d(),
#              map_options=map_options,api_key=api_key)
# '''
# # For GMaps to function, Google requires you obtain and enable an API key:
# #
# #     https://developers.google.com/maps/documentation/javascript/get-api-key
# #
# # Replace the value below with your personal API key:
# #plot.api_key = "AIzaSyAyTUcgbuwbey0p5n5q6BK-PMGHAoAgiJg"
#
# source = ColumnDataSource(
#     data=dict(
#         lat=restPandI.Latitude.tolist(),
#         lon=restPandI.Longitude.tolist()
#         ,size=restPandI.ZIPCODE.tolist()
#         ,color=restPandI.BORO.tolist()
#     )
# )
#
# #color_mapper = CategoricalColorMapper(factors=['hi', 'lo'], palette=[RdBu3[2], RdBu3[0]])
# #color_mapper = LogColorMapper(palette="Viridis5", low=min_median_house_value, high=max_median_house_value)
# color_mapper = LinearColorMapper(palette=Viridis5)
#
# plot.circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, source=source)
#
# #circle = Circle(x="lon", y="lat", fill_color={'field': 'color', 'transform': color_mapper}, fill_alpha=0.5, line_color=None)
# #plot.add_glyph(source, circle)
#
# #color_bar = ColorBar(color_mapper=color_mapper, ticker=BasicTicker(),
# #                     label_standoff=12, border_line_color=None, location=(0,0))
# #plot.add_layout(color_bar, 'right')
#
# #plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
# #output_file("gmap_plot.html")
# output_notebook()
#
# show(plot)

# %%
# this code is from the Bokeh documentation. still doesnt work
from bokeh.io import output_file,output_notebook, show
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap
api_key = "API KEY HERE"

#output_file("gmap.html")

map_options = GMapOptions(lat=40.738, lng=-73.98, map_type="roadmap", zoom=11)

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
p = gmap(google_api_key=api_key, map_options=map_options, title="NY 'Za'")

source = ColumnDataSource(
    data=dict(
        lat=bestPizza.Latitude.tolist(),
        lon=bestPizza.Longitude.tolist()
)
)

p.circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, source=source)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1034">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f5ae1110-9f77-496c-bc87-e7a60f30fc2b" data-root-id="1002"></div>

# %%
## KEPLER is another new thing that doesnt work too well
# !pip install keplergl
# Load an empty map
from keplergl import KeplerGl
map_1.add_data(data=dfTSP, name='data_1')
map_1
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e0c59505952b> in <module>
#       3 # Load an empty map
#       4 from keplergl import KeplerGl
# ----> 5 map_1.add_data(data=dfTSP, name='data_1')
#       6 map_1
#
# NameError: name 'map_1' is not defined
